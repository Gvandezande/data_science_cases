# %%
import h2o
from h2o.estimators import H2ORandomForestEstimator
import pandas as pd

# %%
# data bestand inlezen

insurance_data_filename = 'data/insurance.csv'
df = pd.read_csv(insurance_data_filename)

# check op duplicates, indien zo verwijder direct
df.drop_duplicates(inplace=True)
df_original = df.copy()
duplicate_waarden = df.duplicated().sum()

# %%
import h2o
from h2o.estimators import H2ORandomForestEstimator

# Stap 1: Start de H2O-cluster
h2o.init()

# Stap 2: Laad een dataset (bijv. een CSV-bestand)
# Voor dit voorbeeld gebruiken we een ingebouwde dataset
data = h2o.import_file('data/insurance.csv')
print("Dataset geladen:", data.shape)

df_features = df.drop('charges', axis=1)
y = df['charges']

df_features = pd.get_dummies(df_features, drop_first=True)

# Stap 3: Splits de data in train- en testset
train, test = data.split_frame(ratios=[0.8], seed=42)

# Stap 4: Definieer features (X) en target (y)
x = df_features.copy()
y = df['charges']

# Stap 5: Maak en train een Random Forest-model
rf_model = H2ORandomForestEstimator(ntrees=50, max_depth=20, seed=42)
rf_model.train(x=x, y=y, training_frame=train)

# Stap 6: Maak voorspellingen op de testset
predictions = rf_model.predict(test)
print("Voorspellingen:\n", predictions.head())

# Stap 7: Evalueer het model
performance = rf_model.model_performance(test)
print("Modelprestaties:\n", performance)

# Stap 8: Sluit de H2O-cluster (optioneel)
h2o.cluster().shutdown()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# Warning: Your H2O cluster version is (4 months and 18 days) old.  There may be a newer version available.
# Please download and install the latest version from: https://h2o-release.s3.amazonaws.com/h2o/latest_stable.html
# --------------------------  -----------------------------
# H2O_cluster_uptime:         10 mins 25 secs
# H2O_cluster_timezone:       Europe/Brussels
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.6
# H2O_cluster_version_age:    4 months and 18 days
# H2O_cluster_name:           H2O_from_python_geert_id0b7u
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.933 Gb
# H2O_cluster_total_cores:    16
# H2O_cluster_allowed_cores:  16
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.12.7 final
# --------------------------  -----------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Dataset geladen: (1338, 7)
# ---------------------------------------------------------------------------
# H2OTypeError                              Traceback (most recent call last)
# Cell In[9], line 26
#      24 # Stap 5: Maak en train een Random Forest-model
#      25 rf_model = H2ORandomForestEstimator(ntrees=50, max_depth=20, seed=42)
# ---> 26 rf_model.train(x=x, y=y, training_frame=train)
#      28 # Stap 6: Maak voorspellingen op de testset
#      29 predictions = rf_model.predict(test)
#
# File c:\Users\geert\AppData\Local\Programs\Python\Python312\Lib\site-packages\h2o\estimators\estimator_base.py:103, in H2OEstimator.train(self, x, y, training_frame, offset_column, fold_column, weights_column, validation_frame, max_runtime_secs, ignored_columns, model_id, verbose)
#      85 def train(self, x=None, y=None, training_frame=None, offset_column=None, fold_column=None,
#      86           weights_column=None, validation_frame=None, max_runtime_secs=None, ignored_columns=None,
#      87           model_id=None, verbose=False):
#      88     """
#      89     Train the H2O model.
#      90
#    (...)
#     101     :param bool verbose: Print scoring history to stdout. Defaults to False.
#     102     """
# --> 103     parms = self._make_parms(x=x, y=y, training_frame=training_frame, offset_column=offset_column,
#     104                              fold_column=fold_column, weights_column=weights_column,
#     105                              validation_frame=validation_frame, max_runtime_secs=max_runtime_secs,
#     106                              ignored_columns=ignored_columns, model_id=model_id, verbose=verbose)
#     107     self._train(parms, verbose=verbose)
#     108     return self
#
# File c:\Users\geert\AppData\Local\Programs\Python\Python312\Lib\site-packages\h2o\estimators\estimator_base.py:210, in H2OEstimator._make_parms(self, x, y, training_frame, offset_column, fold_column, weights_column, validation_frame, max_runtime_secs, ignored_columns, model_id, verbose, extend_parms_fn)
#     207 training_frame = H2OFrame._validate(training_frame, 'training_frame',
#     208                                     required=self._options_.get('requires_training_frame', True) and not has_default_training_frame)
#     209 validation_frame = H2OFrame._validate(validation_frame, 'validation_frame')
# --> 210 assert_is_type(y, None, int, str)
#     211 assert_is_type(x, None, int, str, ModelBase, [str, int], {str, int})
#     212 assert_is_type(ignored_columns, None, [str, int], {str, int})
#
# File c:\Users\geert\AppData\Local\Programs\Python\Python312\Lib\site-packages\h2o\utils\typechecks.py:444, in assert_is_type(var, *types, **kwargs)
#     442 etn = _get_type_name(expected_type, dump=", ".join(args[1:]))
#     443 vtn = _get_type_name(type(var))
# --> 444 raise H2OTypeError(var_name=vname, var_value=var, var_type_name=vtn, exp_type_name=etn, message=message,
#     445                    skip_frames=skip_frames)
#
# H2OTypeError: Argument `y` should be a None | integer | string, got Series 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1337, dtype: float64

# %%
import h2o
from h2o.estimators import H2ORandomForestEstimator

# Stap 1: Start de H2O-cluster
h2o.init()

# Stap 2: Laad een dataset (bijv. een CSV-bestand)
# Voor dit voorbeeld gebruiken we een ingebouwde dataset
data = h2o.import_file("https://s3.amazonaws.com/h2o-public-test-data/smalldata/iris/iris_wheader.csv")
print("Dataset geladen:", data.shape)

# Stap 3: Splits de data in train- en testset
train, test = data.split_frame(ratios=[0.8], seed=42)

# Stap 4: Definieer features (X) en target (y)
x = train.columns[:-1]  # Alle kolommen behalve de laatste
y = "class"  # De laatste kolom is de target (iris-klasse)

# Stap 5: Maak en train een Random Forest-model
rf_model = H2ORandomForestEstimator(ntrees=50, max_depth=20, seed=42)
rf_model.train(x=x, y=y, training_frame=train)

# Stap 6: Maak voorspellingen op de testset
predictions = rf_model.predict(test)
print("Voorspellingen:\n", predictions.head())

# Stap 7: Evalueer het model
performance = rf_model.model_performance(test)
print("Modelprestaties:\n", performance)

# Stap 8: Sluit de H2O-cluster (optioneel)
h2o.cluster().shutdown()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# Warning: Your H2O cluster version is (4 months and 18 days) old.  There may be a newer version available.
# Please download and install the latest version from: https://h2o-release.s3.amazonaws.com/h2o/latest_stable.html
# --------------------------  -----------------------------
# H2O_cluster_uptime:         12 mins 20 secs
# H2O_cluster_timezone:       Europe/Brussels
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.6
# H2O_cluster_version_age:    4 months and 18 days
# H2O_cluster_name:           H2O_from_python_geert_id0b7u
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.933 Gb
# H2O_cluster_total_cores:    16
# H2O_cluster_allowed_cores:  16
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.12.7 final
# --------------------------  -----------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Dataset geladen: (150, 5)
# drf Model Build progress: |██████████████████████████████████████████████████████| (done) 100%
# drf prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# Voorspellingen:
#  predict            Iris-setosa    Iris-versicolor    Iris-virginica
# Iris-setosa        0.996534              0               0.00346593
# Iris-setosa        0.996466              0               0.00353442
# Iris-setosa        0.996534              0               0.00346593
# Iris-setosa        0.996534              0               0.00346593
# Iris-setosa        0.996534              0               0.00346593
# Iris-setosa        0.996534              0               0.00346593
# Iris-setosa        0.996534              0               0.00346593
# Iris-setosa        0.996534              0               0.00346593
# Iris-versicolor    0.000553324           0.995983        0.00346401
# Iris-versicolor    0.000553324           0.995983        0.00346401
# [10 rows x 4 columns]
#
# Modelprestaties:
#  ModelMetricsMultinomial: drf
# ** Reported on test data. **
#
# MSE: 0.023974625446180696
# RMSE: 0.15483741616993194
# LogLoss: 0.07139819350501733
# Mean Per-Class Error: 0.030303030303030304
# AUC table was not computed: it is either disabled (model parameter 'auc_type' was set to AUTO or NONE) or the domain size exceeds the limit (maximum is 50 domains).
# AUCPR table was not computed: it is either disabled (model parameter 'auc_type' was set to AUTO or NONE) or the domain size exceeds the limit (maximum is 50 domains).
#
# Confusion Matrix: Row labels: Actual class; Column labels: Predicted class
# Iris-setosa    Iris-versicolor    Iris-virginica    Error      Rate
# -------------  -----------------  ----------------  ---------  ------
# 8              0                  0                 0          0 / 8
# 0              10                 0                 0          0 / 10
# 0              1                  10                0.0909091  1 / 11
# 8              11                 10                0.0344828  1 / 29
#
# Top-3 Hit Ratios:
# k    hit_ratio
# ---  -----------
# 1    0.965517
# 2    1
# 3    1
# H2O session _sid_88bb closed.
